# %%
import io
import numpy as np
from PIL import Image

# %%
datapath = 'img/0A4nmNFa3HNGiyJLGoHJUg.jpeg'
img = Image.open(datapath)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x22A92AFD710>

# %%
path2 = 'spec/0A4nmNFa3HNGiyJLGoHJUg.png'
img2 = Image.open(path2)

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256 at 0x22A946AFA58>

# %%
np.asarray(img2.convert('RGB')).shape
# Out:
# (256, 256, 3)

# %%
np.asarray(img).shape
# Out:
# (640, 640, 3)

# %%
import os
os.listdir('img')
# Out:
# ['0A4nmNFa3HNGiyJLGoHJUg.jpeg', '0A5gdlrpAuQqZ2iFgnqBFW.jpeg']

# %%
import os
import glob
import numpy as np
from PIL import Image


def dataset_load(datapath, labelpath, imgsize):
    datalist = os.listdir(datapath)
    datasize = len(datalist)
    
    data_ = np.zeros((datasize, imgsize, imgsize, 3))
    label_ = np.zeros((datasize, imgsize, imgsize, 3))
    nonelist = []
    for i, fname in enumerate(datalist):
        #print('i', i)
        #print('file', fname)
        #print(os.path.join(labelpath, fname[:-4] + '*'))
        if glob.glob(os.path.join(labelpath, fname[:-4] + '*')):
        #f os.path.isfile(os.path.join(labelpath, fname[:-4] + 'png')):
            #print('there is file')
            img_d = Image.open(os.path.join(datapath, fname)
                              ).resize((imgsize, imgsize))
            img_l = Image.open(os.path.join(labelpath, fname[:-4]+'png')
                              ).convert('RGB').resize((imgsize, imgsize))
            data_[i] = np.asarray(img_d)
            label_[i] = np.asarray(img_l)
            
        else:
            nonelist.append(i)
            
    data = np.delete(data_, nonelist, 0)
    label = np.delete(label_, nonelist, 0)
    return data, label

# %%
d, l = dataset_load('img', 'spec', 256)

# %%
d.shape
# Out:
# (2, 256, 256, 3)

# %%
l.shape
# Out:
# (2, 256, 256, 3)

# %%
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]]])
