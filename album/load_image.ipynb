# %%
import zipfile
import io
import numpy as np
from PIL import Image

# %%
datadir = 'data/images_part1.zip'
with zipfile.ZipFile(datadir) as data:
    datalist = data.namelist()
    
    #for fil in datalist[1:]:
    #    print(fil)
    #with data.open(datalist[1]) as data1:
        #print(data1.read())
    img = Image.open(io.BytesIO(data.read(datalist[1])))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FE55011D908>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
np.asarray(img).shape
# Out:
# (640, 640, 3)
